# %%
# !pip install opencv-python
import cv2

def detect_collision(frame):
    # Function to detect collision in the given frame
    # Replace this function with your collision detection algorithm
    # For simplicity, this function just checks if there's any non-black pixel in the frame
    return cv2.countNonZero(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)) > 0

def main():
    # Accessing the webcam
    cap = cv2.VideoCapture(0)

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        # Display the frame
        cv2.imshow('Webcam', frame)

        # Check for collision
        collision_detected = detect_collision(frame)

        if collision_detected:
            print("Collision detected!")
            # You can add code here to trigger some action upon collision detection

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release the webcam and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# ...
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# ...

# %%
import cv2
import csv
import os

# Global variables
COLLISION_LABEL = 1
NO_COLLISION_LABEL = 0
OUTPUT_DIR = "collision_images"
DATA_FILE = "collision_data.csv"

def detect_collision(frame):
    # Function to detect collision in the given frame
    # Replace this function with your collision detection algorithm
    # For simplicity, this function just checks if there's any non-black pixel in the frame
    return cv2.countNonZero(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)) > 0

def save_data(label, frame):
    # Save label and corresponding image to CSV file
    with open(DATA_FILE, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([label, os.path.join(OUTPUT_DIR, f"{label}_{len(os.listdir(OUTPUT_DIR))}.jpg")])
    cv2.imwrite(os.path.join(OUTPUT_DIR, f"{label}_{len(os.listdir(OUTPUT_DIR))}.jpg"), frame)

def main():
    # Accessing the webcam
    cap = cv2.VideoCapture(0)

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        # Display the frame
        cv2.imshow('Webcam', frame)

        # Check for collision
        collision_detected = detect_collision(frame)

        if collision_detected:
            print("Collision detected!")
            save_data(COLLISION_LABEL, frame)
            # You can add code here to trigger some action upon collision detection

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release the webcam and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    # Create output directory if it doesn't exist
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    # Create or clear the data file
    with open(DATA_FILE, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Label', 'Image'])

    main()
# Out:
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# ...

# %%
import cv2
import csv
import time

def detect_collision(frame):
    # Function to detect collision in the given frame
    # Replace this function with your collision detection algorithm
    # For simplicity, this function just checks if there's any non-black pixel in the frame
    return cv2.countNonZero(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)) > 0

def main():
    # Accessing the webcam
    cap = cv2.VideoCapture(0)

    # Create CSV file to save collision labels and file paths
    csv_file = open('collision_data.csv', 'w', newline='')
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(['Label', 'Image Path'])

    # Variable to control start/stop of data collection
    collecting_data = False

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        # Display the frame
        cv2.imshow('Webcam', frame)

        # Check for collision
        collision_detected = detect_collision(frame)

        if collecting_data:
            if collision_detected:
                print("Collision detected!")
                label = 1
            else:
                print("No collision detected.")
                label = 0

            # Save collision label and corresponding image
            timestamp = int(time.time())
            image_path = f"images/{label}_{timestamp}.png"
            cv2.imwrite(image_path, frame)
            csv_writer.writerow([label, image_path])

        # Break the loop if 'q' is pressed
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('s'):  # Start/Stop data collection
            collecting_data = not collecting_data
            if collecting_data:
                print("Data collection started.")
            else:
                print("Data collection stopped.")

    # Release the webcam, close CSV file, and close OpenCV windows
    cap.release()
    csv_file.close()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# Data collection started.
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# ...

# %%
import cv2
import csv
import time

# Function to simulate distance measurement
def measure_distance():
    # Simulate distance measurement (in centimeters)
    # Here, we randomly generate a distance between 0 and 200cm
    import random
    return random.randint(0, 200)

def detect_collision(frame, distance_threshold=10):
    # Function to detect collision based on distance measurement
    distance = measure_distance()
    if distance <= distance_threshold:
        return True
    else:
        # For simplicity, we can still use the existing collision detection function
        return cv2.countNonZero(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)) > 0
    
def save_data(label, frame):
    # Save label and corresponding image to CSV file
    with open(DATA_FILE, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([label, os.path.join(OUTPUT_DIR, f"{label}_{len(os.listdir(OUTPUT_DIR))}.jpg")])
    cv2.imwrite(os.path.join(OUTPUT_DIR, f"{label}_{len(os.listdir(OUTPUT_DIR))}.jpg"), frame)

def main():
    # Accessing the webcam
    cap = cv2.VideoCapture(0)

    # Create CSV file to save collision labels and file paths
    csv_file = open('collision_data.csv', 'w', newline='')
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(['Label', 'Image Path'])

    # Variable to control start/stop of data collection
    collecting_data = False

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        # Display the frame
        cv2.imshow('Webcam', frame)

        # Check for collision
        collision_detected = detect_collision(frame)

        if collecting_data:
            if collision_detected:
                print("Collision detected!")
                label = 1
            else:
                print("No collision detected.")
                label = 0

            # Save collision label and corresponding image
            timestamp = int(time.time())
            image_path = f"images/{label}_{timestamp}.png"
            cv2.imwrite(image_path, frame)
            csv_writer.writerow([label, image_path])

        # Break the loop if 'q' is pressed
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('s'):  # Start/Stop data collection
            collecting_data = not collecting_data
            if collecting_data:
                print("Data collection started.")
            else:
                print("Data collection stopped.")

    # Release the webcam, close CSV file, and close OpenCV windows
    cap.release()
    csv_file.close()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    # Create output directory if it doesn't exist
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    # Create or clear the data file
    with open(DATA_FILE, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Label', 'Image'])

    main()
# Out:
# Data collection started.
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# ...

# %%
import cv2
import csv
import time
import os

# Function to simulate distance measurement
def measure_distance():
    # Simulate distance measurement (in centimeters)
    # Here, we randomly generate a distance between 0 and 200cm
    import random
    return random.randint(0, 200)

def detect_collision(frame, distance_threshold=5):
    # Function to detect collision based on distance measurement
    distance = measure_distance()
    if distance <= distance_threshold:
        return True
    else:
        # For simplicity, we can still use the existing collision detection function
        return cv2.countNonZero(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)) > 0
    
def save_data(label, frame):
    # Save label and corresponding image to CSV file
    with open(DATA_FILE, mode='a', newline='') as file:
        writer = csv.writer(file)
        image_path = os.path.join(OUTPUT_DIR, f"{label}_{len(os.listdir(OUTPUT_DIR))}.jpg")
        writer.writerow([label, image_path])
    cv2.imwrite(image_path, frame)

def main():
    # Accessing the webcam
    cap = cv2.VideoCapture(0)

    # Variable to control start/stop of data collection
    collecting_data = False

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        # Display the frame
        cv2.imshow('Webcam', frame)

        # Check for collision
        collision_detected = detect_collision(frame)

        if collecting_data:
            if collision_detected:
                print("Collision detected!")
                label = 1
            else:
                print("No collision detected.")
                label = 0

            # Save collision label and corresponding image
            save_data(label, frame)

        # Break the loop if 'q' is pressed
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('s'):  # Start/Stop data collection
            collecting_data = not collecting_data
            if collecting_data:
                print("Data collection started.")
            else:
                print("Data collection stopped.")

    # Release the webcam and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    # Define output directory and data file
    OUTPUT_DIR = "images"
    DATA_FILE = "collision_data.csv"

    # Create output directory if it doesn't exist
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    # Create or clear the data file
    with open(DATA_FILE, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Label', 'Image'])

    main()
# Out:
# Data collection started.
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# ...

# %%
import cv2
import csv
import time
import os

# Function to simulate distance measurement
def measure_distance():
    # Simulate distance measurement (in centimeters)
    # Here, we randomly generate a distance between 0 and 200cm
    import random
    return random.randint(0, 200)

def detect_collision(frame, distance_threshold=1):
    # Function to detect collision based on distance measurement
    distance = measure_distance()
    if distance <= distance_threshold:
        return True
    else:
        # For simplicity, we can still use the existing collision detection function
        return cv2.countNonZero(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)) > 0
    
def save_data(label, frame):
    # Save label and corresponding image to CSV file
    with open(DATA_FILE, mode='a', newline='') as file:
        writer = csv.writer(file)
        image_path = os.path.join(OUTPUT_DIR, f"{label}_{len(os.listdir(OUTPUT_DIR))}.jpg")
        writer.writerow([label, image_path])
    cv2.imwrite(image_path, frame)

def main():
    # Accessing the webcam
    cap = cv2.VideoCapture(0)

    # Variable to control start/stop of data collection
    collecting_data = False

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        # Display the frame
        cv2.imshow('Webcam', frame)

        # Check for collision
        collision_detected = detect_collision(frame)

        if collecting_data:
            if collision_detected:
                print("Collision detected!")
                label = 1
            else:
                print("No collision detected.")
                label = 0

            # Save collision label and corresponding image
            save_data(label, frame)
            print("Data saved.")

        # Break the loop if 'q' is pressed
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('s'):  # Start/Stop data collection
            collecting_data = not collecting_data
            if collecting_data:
                print("Data collection started.")
            else:
                print("Data collection stopped.")

    # Release the webcam and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    # Define output directory and data file
    OUTPUT_DIR = "images"
    DATA_FILE = "collision_data.csv"

    # Create output directory if it doesn't exist
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    # Create or clear the data file
    with open(DATA_FILE, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Label', 'Image'])

    main()
# Out:
# Data collection started.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# ...

# %%
import cv2
import csv
import time
import os

# Function to simulate distance measurement
def measure_distance():
    # Simulate distance measurement (in centimeters)
    # Here, we randomly generate a distance between 0 and 200cm
    import random
    return random.randint(0, 200)

def detect_collision(frame, distance_threshold=1):
    # Function to detect collision based on distance measurement
    distance = measure_distance()
    if distance <= distance_threshold:
        return True
    else:
        # For simplicity, we can still use the existing collision detection function
        return cv2.countNonZero(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)) > 0
    
def save_data(label, frame):
    # Save label and corresponding image to CSV file
    with open(DATA_FILE, mode='a', newline='') as file:
        writer = csv.writer(file)
        image_path = os.path.join(OUTPUT_DIR, f"{label}_{len(os.listdir(OUTPUT_DIR))}.jpg")
        writer.writerow([label, image_path])
    cv2.imwrite(image_path, frame)

def main():
    # Accessing the webcam
    cap = cv2.VideoCapture(0)

    # Variable to control start/stop of data collection
    collecting_data = False

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        # Display the frame
        cv2.imshow('Webcam', frame)

        # Check for collision
        collision_detected = detect_collision(frame)

        if collecting_data:
            if collision_detected:
                print("Collision detected!")
                label = 1
            else:
                print("No collision detected.")
                label = 0

            # Save collision label and corresponding image
            save_data(label, frame)
            print("Data saved.")
        else:
            print("No collision detected.")  # Print when not collecting data

        # Break the loop if 'q' is pressed
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('s'):  # Start/Stop data collection
            collecting_data = not collecting_data
            if collecting_data:
                print("Data collection started.")
            else:
                print("Data collection stopped.")

    # Release the webcam and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    # Define output directory and data file
    OUTPUT_DIR = "images"
    DATA_FILE = "collision_data.csv"

    # Create output directory if it doesn't exist
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    # Create or clear the data file
    with open(DATA_FILE, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Label', 'Image'])

    main()
# Out:
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# No collision detected.
# ...

# %%
import cv2
import csv
import time
import os

# Function to simulate distance measurement
def measure_distance():
    # Simulate distance measurement (in centimeters)
    # Here, we randomly generate a distance between 0 and 200cm
    import random
    return random.randint(0, 2)

def detect_collision(frame, distance_threshold=1):
    # Function to detect collision based on distance measurement
    distance = measure_distance()
    if distance <= distance_threshold:
        return True
    else:
        # For simplicity, we can still use the existing collision detection function
        return cv2.countNonZero(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)) > 0
    
def save_data(label, frame):
    # Save label and corresponding image to CSV file
    with open(DATA_FILE, mode='a', newline='') as file:
        writer = csv.writer(file)
        image_path = os.path.join(OUTPUT_DIR, f"{label}_{len(os.listdir(OUTPUT_DIR))}.jpg")
        writer.writerow([label, image_path])
    cv2.imwrite(image_path, frame)

def main():
    # Accessing the webcam
    cap = cv2.VideoCapture(0)

    # Variable to control start/stop of data collection
    collecting_data = False

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        # Display the frame
        cv2.imshow('Webcam', frame)

        # Check for collision
        collision_detected = detect_collision(frame)

        if collecting_data:
            if collision_detected:
                print("Collision detected!")
                label = 1
            else:
                print("No collision detected.")
                label = 0

            # Save collision label and corresponding image
            save_data(label, frame)
            print("Data saved.")

        # Break the loop if 'q' is pressed
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('s'):  # Start/Stop data collection
            collecting_data = not collecting_data
            if collecting_data:
                print("Data collection started.")
            else:
                print("Data collection stopped.")

    # Release the webcam and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    # Define output directory and data file
    OUTPUT_DIR = "images"
    DATA_FILE = "collision_data.csv"

    # Create output directory if it doesn't exist
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    # Create or clear the data file
    with open(DATA_FILE, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Label', 'Image'])

    main()
# Out:
# Data collection started.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# ...

# %%
import cv2
import csv
import time
import os

# Function to simulate distance measurement
def measure_distance():
    # Simulate distance measurement (in centimeters)
    # Here, we randomly generate a distance between 0 and 200cm
    import random
    return random.randint(0, 2)

def detect_collision(frame, distance_threshold=1):
    # Function to detect collision based on distance measurement
    distance = measure_distance()
    if distance <= distance_threshold:
        return True
    else:
        # For simplicity, we can still use the existing collision detection function
        return cv2.countNonZero(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)) > 0
    
def save_data(label, frame):
    # Save label and corresponding image to CSV file
    with open(DATA_FILE, mode='a', newline='') as file:
        writer = csv.writer(file)
        image_path = os.path.join(OUTPUT_DIR, f"{label}_{len(os.listdir(OUTPUT_DIR))}.jpg")
        writer.writerow([label, image_path])
    cv2.imwrite(image_path, frame)

def main():
    # Accessing the webcam
    cap = cv2.VideoCapture(0)

    # Variable to control start/stop of data collection
    collecting_data = False

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        # Display the frame
        cv2.imshow('Webcam', frame)

        # Check for collision
        collision_detected = detect_collision(frame)

        if collecting_data:
            if collision_detected:
                print("Collision detected!")
                label = 1
            else:
                print("No collision detected.")
                label = 0

            # Save collision label and corresponding image
            save_data(label, frame)
            print("Data saved.")

        # Break the loop if 'q' is pressed
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('s'):  # Start/Stop data collection
            collecting_data = not collecting_data
            if collecting_data:
                print("Data collection started.")
            else:
                print("Data collection stopped.")

    # Release the webcam and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    # Define output directory and data file
    OUTPUT_DIR = "images"
    DATA_FILE = "collision_data.csv"

    # Create output directory if it doesn't exist
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    # Create or clear the data file
    with open(DATA_FILE, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Label', 'Image'])

    main()
# Out:
# Data collection started.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# ...

# %%
import cv2
import csv
import time
import os

# Function to simulate distance measurement
def measure_distance():
    # Simulate distance measurement (in centimeters)
    # Here, we randomly generate a distance between 0 and 200cm
    import random
    return random.randint(0, 200)

def detect_collision(frame, distance_threshold=100):
    # Function to detect collision based on distance measurement
    distance = measure_distance()
    if distance <= distance_threshold:
        return True
    else:
        # For simplicity, we can still use the existing collision detection function
        return cv2.countNonZero(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)) > 0
    
def save_data(label, frame):
    # Save label and corresponding image to CSV file
    with open(DATA_FILE, mode='a', newline='') as file:
        writer = csv.writer(file)
        image_path = os.path.join(OUTPUT_DIR, f"{label}_{len(os.listdir(OUTPUT_DIR))}.jpg")
        writer.writerow([label, image_path])
    cv2.imwrite(image_path, frame)

def main():
    # Accessing the webcam
    cap = cv2.VideoCapture(0)

    # Variable to control start/stop of data collection
    collecting_data = False

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        # Display the frame
        cv2.imshow('Webcam', frame)

        # Check for collision
        collision_detected = detect_collision(frame)

        if collecting_data:
            if collision_detected:
                print("Collision detected!")
                label = 1
            else:
                print("No collision detected.")
                label = 0

            # Save collision label and corresponding image
            save_data(label, frame)
            print("Data saved.")

        # Break the loop if 'q' is pressed
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('s'):  # Start/Stop data collection
            collecting_data = not collecting_data
            if collecting_data:
                print("Data collection started.")
            else:
                print("Data collection stopped.")

    # Release the webcam and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    # Define output directory and data file
    OUTPUT_DIR = "images"
    DATA_FILE = "collision_data.csv"

    # Create output directory if it doesn't exist
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    # Create or clear the data file
    with open(DATA_FILE, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Label', 'Image'])

    main()
# Out:
# Data collection started.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# ...

# %%
# prompt: write a code to identify the collision or no collision using webcame

import cv2
import numpy as np

# Initialize video capture object
vid = cv2.VideoCapture(0)

while True:
    # Capture the frame
    ret, frame = vid.read()

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect circles in the frame
    circles = cv2.HoughCircles(gray, cv2.HOUGH_GRADIENT, 1, 20, param1=50, param2=30, minRadius=0, maxRadius=0)

    # Check if any circles are detected
    if circles is not None:
        # Draw the circles on the frame
        circles = np.uint16(np.around(circles))
        for i in circles[0, :]:
            cv2.circle(frame, (i[0], i[1]), i[2], (0, 255, 0), 2)
            cv2.circle(frame, (i[0], i[1]), 2, (0, 0, 255), 3)

        # Check if any circles are colliding
        for i in range(len(circles[0, :])):
            for j in range(i + 1, len(circles[0, :])):
                # Calculate the distance between the centers of the circles
                distance = np.sqrt((circles[0, i][0] - circles[0, j][0]) ** 2 + (circles[0, i][1] - circles[0, j][1]) ** 2)

                # Check if the distance is less than the sum of the radii
                if distance < circles[0, i][2] + circles[0, j][2]:
                    # Print a message indicating a collision
                    print("Collision detected!")

    # Display the frame
    cv2.imshow('frame', frame)

    # Check if the user pressed the 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object
vid.release()

# Close all windows
cv2.destroyAllWindows()
# Out:
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# Collision detected!
# ...

# %%
# prompt: write a code to identify the collision or no collision using webcame if the object within 50cm which is considered as a collision

import cv2

# Initialize the video capture object
vid = cv2.VideoCapture(0)

while True:
    # Capture the frame
    ret, frame = vid.read()

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    # Draw a rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Calculate the distance between the camera and the face
        distance = calculate_distance(frame, x, y, w, h)

        # Check if the distance is less than 50cm
        if distance < 50:
            # Display a message indicating a collision
            cv2.putText(frame, "Collision!", (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)

    # Display the frame
    cv2.imshow('frame', frame)

    # Check for the 'q' key to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object
vid.release()

# Destroy all windows
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19864/2311723949.py in <module>
#      14
#      15     # Detect faces in the frame
# ---> 16     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#      17
#      18     # Draw a rectangle around the faces
#
# NameError: name 'face_cascade' is not defined

# %%
import cv2
import numpy as np

# Initialize the video capture object
vid = cv2.VideoCapture(0)

while True:
    # Capture the frame
    ret, frame = vid.read()

    # Check if the frame is empty
    if not ret:
        break

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    # Draw a rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Calculate the distance between the camera and the face
        distance = calculate_distance(frame, x, y, w, h)

        # Check if the distance is less than 50cm
        if distance < 50:
            # Display a message indicating a collision
            cv2.putText(frame, "Collision!", (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)

    # Display the frame
    cv2.imshow('frame', frame)

    # Check for the 'q' key to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object
vid.release()

# Destroy all windows
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19864/2190056002.py in <module>
#      17
#      18     # Detect faces in the frame
# ---> 19     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#      20
#      21     # Draw a rectangle around the faces
#
# NameError: name 'face_cascade' is not defined

# %%
import cv2
import numpy as np

# Initialize the face cascade
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Function to calculate the distance between the camera and the face
def calculate_distance(frame, x, y, w, h):
    # Assuming some logic to calculate the distance based on face dimensions
    # Here, we simulate distance measurement (in centimeters)
    import random
    return random.randint(0, 200)

# Initialize the video capture object
vid = cv2.VideoCapture(0)

while True:
    # Capture the frame
    ret, frame = vid.read()

    # Check if the frame is empty
    if not ret:
        break

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    # Draw a rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Calculate the distance between the camera and the face
        distance = calculate_distance(frame, x, y, w, h)

        # Check if the distance is less than 50cm
        if distance < 50:
            # Display a message indicating a collision
            cv2.putText(frame, "Collision!", (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)

    # Display the frame
    cv2.imshow('frame', frame)

    # Check for the 'q' key to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object
vid.release()

# Destroy all windows
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Load YOLO
net = cv2.dnn.readNet("yolov3.weights", "yolov3.cfg")
classes = []
with open("coco.names", "r") as f:
    classes = [line.strip() for line in f]

# Initialize the video capture object
vid = cv2.VideoCapture(0)

while True:
    # Capture the frame
    ret, frame = vid.read()

    # Check if the frame is empty
    if not ret:
        break

    # Get the height and width of the frame
    height, width, _ = frame.shape

    # Create a blob from the frame
    blob = cv2.dnn.blobFromImage(frame, 1/255.0, (416, 416), swapRB=True, crop=False)

    # Set the input to the network
    net.setInput(blob)

    # Get the output layer names
    layer_names = net.getLayerNames()
    output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]

    # Forward pass through the network
    outputs = net.forward(output_layers)

    # Initialize lists for detected objects
    class_ids = []
    confidences = []
    boxes = []

    # Loop over each output
    for output in outputs:
        for detection in output:
            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]

            if confidence > 0.5:  # Filter out weak detections
                # Get the coordinates of the bounding box
                center_x = int(detection[0] * width)
                center_y = int(detection[1] * height)
                w = int(detection[2] * width)
                h = int(detection[3] * height)

                # Calculate the top-left corner of the bounding box
                x = int(center_x - w / 2)
                y = int(center_y - h / 2)

                # Append the detection information to the lists
                class_ids.append(class_id)
                confidences.append(float(confidence))
                boxes.append([x, y, w, h])

    # Perform non-maximum suppression to eliminate redundant overlapping boxes
    indices = cv2.dnn.NMSBoxes(boxes, confidences, 0.5, 0.4)

    # Draw the final bounding boxes on the frame
    for i in indices:
        i = i[0]
        box = boxes[i]
        x, y, w, h = box
        label = str(classes[class_ids[i]])
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
        cv2.putText(frame, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        # Calculate the distance between the camera and the object (you need to implement this function)
        distance = calculate_distance(frame, x, y, w, h)

        # Check if the distance is less than 50cm
        if distance < 50:
            cv2.putText(frame, "Collision!", (x, y - 30), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)

    # Display the frame
    cv2.imshow('frame', frame)

    # Check for the 'q' key to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object
vid.release()

# Destroy all windows
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19864/4071030710.py in <module>
#       3
#       4 # Load YOLO
# ----> 5 net = cv2.dnn.readNet("yolov3.weights", "yolov3.cfg")
#       6 classes = []
#       7 with open("coco.names", "r") as f:
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\dnn\src\darknet\darknet_importer.cpp:210: error: (-212:Parsing error) Failed to open NetParameter file: yolov3.cfg in function 'cv::dnn::dnn4_v20220524::readNetFromDarknet'

# %%
import cv2
import numpy as np

# Initialize the video capture object
vid = cv2.VideoCapture(0)

# Define the region of interest (ROI) coordinates
roi_x, roi_y, roi_w, roi_h = 100, 100, 200, 200

# Initialize variables for motion detection
prev_frame = None

while True:
    # Capture the frame
    ret, frame = vid.read()

    # Check if the frame is empty
    if not ret:
        break

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur to reduce noise
    gray_blur = cv2.GaussianBlur(gray, (21, 21), 0)

    # Initialize previous frame if not exists
    if prev_frame is None:
        prev_frame = gray_blur
        continue

    # Compute absolute difference between current frame and previous frame
    frame_diff = cv2.absdiff(prev_frame, gray_blur)

    # Apply threshold to get binary image
    _, thresh = cv2.threshold(frame_diff, 30, 255, cv2.THRESH_BINARY)

    # Dilate the thresholded image to fill gaps
    thresh = cv2.dilate(thresh, None, iterations=2)

    # Find contours of motion
    contours, _ = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through contours
    for contour in contours:
        # Compute bounding box of contour
        (x, y, w, h) = cv2.boundingRect(contour)

        # Check if bounding box is within ROI
        if x > roi_x and y > roi_y and x + w < roi_x + roi_w and y + h < roi_y + roi_h:
            # Display a message indicating a collision
            cv2.putText(frame, "Collision!", (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)

    # Update previous frame
    prev_frame = gray_blur

    # Display the frame
    cv2.imshow('frame', frame)

    # Check for the 'q' key to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object
vid.release()

# Destroy all windows
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Initialize the video capture object
vid = cv2.VideoCapture(0)

# Define the region of interest (ROI) coordinates
roi_x, roi_y, roi_w, roi_h = 100, 100, 200, 200

# Function to calculate the distance between two points
def calculate_distance(x1, y1, x2, y2):
    return np.sqrt((x2 - x1)**2 + (y2 - y1)**2)

while True:
    # Capture the frame
    ret, frame = vid.read()

    # Check if the frame is empty
    if not ret:
        break

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur to reduce noise
    gray_blur = cv2.GaussianBlur(gray, (21, 21), 0)

    # Find contours of motion within the ROI
    contours, _ = cv2.findContours(gray_blur[roi_y:roi_y+roi_h, roi_x:roi_x+roi_w].copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through contours
    for contour in contours:
        # Compute centroid of contour
        M = cv2.moments(contour)
        if M["m00"] != 0:
            cX = int(M["m10"] / M["m00"]) + roi_x
            cY = int(M["m01"] / M["m00"]) + roi_y

            # Calculate distance from centroid to ROI center
            distance = calculate_distance(cX, cY, roi_x + roi_w // 2, roi_y + roi_h // 2)

            # Check if distance is less than a threshold
            if distance < 50:
                # Display a message indicating a collision
                cv2.putText(frame, "Collision!", (cX, cY - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)

    # Draw ROI rectangle
    cv2.rectangle(frame, (roi_x, roi_y), (roi_x + roi_w, roi_y + roi_h), (255, 0, 0), 2)

    # Display the frame
    cv2.imshow('frame', frame)

    # Check for the 'q' key to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object
vid.release()

# Destroy all windows
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Initialize the video capture object
vid = cv2.VideoCapture(0)

# Define the region of interest (ROI) coordinates
roi_x, roi_y, roi_w, roi_h = 100, 100, 200, 200

# Function to calculate the distance between two points
def calculate_distance(x1, y1, x2, y2):
    return np.sqrt((x2 - x1)**2 + (y2 - y1)**2)

while True:
    # Capture the frame
    ret, frame = vid.read()

    # Check if the frame is empty
    if not ret:
        break

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur to reduce noise
    gray_blur = cv2.GaussianBlur(gray, (21, 21), 0)

    # Find contours of motion within the ROI
    contours, _ = cv2.findContours(gray_blur[roi_y:roi_y+roi_h, roi_x:roi_x+roi_w].copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate through contours
    for contour in contours:
        # Compute centroid of contour
        M = cv2.moments(contour)
        if M["m00"] != 0:
            cX = int(M["m10"] / M["m00"]) + roi_x
            cY = int(M["m01"] / M["m00"]) + roi_y

            # Calculate distance from centroid to ROI center
            distance = calculate_distance(cX, cY, roi_x + roi_w // 2, roi_y + roi_h // 2)

            # Check if distance is less than a threshold
            if distance < 50:
                # Display a message indicating a collision
                cv2.putText(frame, "Collision!", (cX, cY - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)

    # Draw ROI rectangle
    cv2.rectangle(frame, (roi_x, roi_y), (roi_x + roi_w, roi_y + roi_h), (255, 0, 0), 2)

    # Display the frame
    cv2.imshow('frame', frame)

    # Check for the 'q' key to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object
vid.release()

# Destroy all windows
cv2.destroyAllWindows()

# %%
import cv2
import csv
import time
import os

# Function to simulate distance measurement
def measure_distance():
    # Simulate distance measurement (in centimeters)
    # Here, we randomly generate a distance between 0 and 200cm
    import random
    return random.randint(0, 200)

def detect_collision(frame, distance_threshold=100):
    # Function to detect collision based on distance measurement
    distance = measure_distance()
    if distance <= distance_threshold:
        return True
    else:
        # For simplicity, we can still use the existing collision detection function
        return cv2.countNonZero(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)) > 0
    
def save_data(label, frame):
    # Save label and corresponding image to CSV file
    global DATA_FILE, OUTPUT_DIR
    with open(DATA_FILE, mode='a', newline='') as file:
        writer = csv.writer(file)
        image_path = os.path.join(OUTPUT_DIR, f"{label}_{len(os.listdir(OUTPUT_DIR))}.jpg")
        writer.writerow([label, image_path])
    cv2.imwrite(image_path, frame)

def main():
    # Accessing the webcam
    cap = cv2.VideoCapture(0)

    # Variable to control start/stop of data collection
    collecting_data = False

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        # Display the frame
        cv2.imshow('Webcam', frame)

        # Check for collision
        collision_detected = detect_collision(frame)

        if collecting_data:
            if collision_detected:
                print("Collision detected!")
                label = 1
            else:
                print("No collision detected.")
                label = 0

            # Save collision label and corresponding image
            save_data(label, frame)
            print("Data saved.")

        # Break the loop if 'q' is pressed
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('s'):  # Start/Stop data collection
            collecting_data = not collecting_data
            if collecting_data:
                print("Data collection started.")
            else:
                print("Data collection stopped.")

    # Release the webcam and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    # Define output directory and data file
    OUTPUT_DIR = "images"
    DATA_FILE = "collision_data.csv"

    # Create output directory if it doesn't exist
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    # Create or clear the data file
    with open(DATA_FILE, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Label', 'Image'])

    main()
# Out:
# Data collection started.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# ...

# %%
import cv2
import csv
import time
import os

# Function to simulate distance measurement
def measure_distance():
    # Simulate distance measurement (in centimeters)
    # Here, we randomly generate a distance between 0 and 200cm
    import random
    return random.randint(0, 200)

def detect_collision(frame, distance_threshold=100):
    # Function to detect collision based on distance measurement
    distance = measure_distance()
    if distance <= distance_threshold:
        return True
    else:
        # For simplicity, we can still use the existing collision detection function
        return cv2.countNonZero(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)) > 0

def save_data(label, frame):
    # Save label and corresponding image to CSV file
    global DATA_FILE, OUTPUT_DIR
    with open(DATA_FILE, mode='a', newline='') as file:
        writer = csv.writer(file)
        image_path = os.path.join(OUTPUT_DIR, f"{label}_{len(os.listdir(OUTPUT_DIR))}.jpg")
        writer.writerow([label, image_path])
    cv2.imwrite(image_path, frame)

def main():
    # Accessing the webcam
    cap = cv2.VideoCapture(0)

    # Variable to control start/stop of data collection
    collecting_data = False

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        # Display the frame
        cv2.imshow('Webcam', frame)

        # Check for collision
        collision_detected = detect_collision(frame)

        if collecting_data:
            if collision_detected:
                print("Collision detected!")
                label = 1
            else:
                print("No collision detected.")
                label = 0

            # Save collision label and corresponding image
            save_data(label, frame)
            print("Data saved.")

        # Break the loop if 'q' is pressed
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('s'):  # Start/Stop data collection
            collecting_data = not collecting_data
            if collecting_data:
                print("Data collection started.")
            else:
                print("Data collection stopped.")

    # Release the webcam and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    # Define output directory and data file
    OUTPUT_DIR = "images"
    DATA_FILE = "collision_data.csv"

    # Create output directory if it doesn't exist
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    # Create or clear the data file
    with open(DATA_FILE, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Label', 'Image'])

    main()
# Out:
# Data collection started.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# ...

# %%
import cv2
import csv
import time
import os

# Function to simulate distance measurement
def measure_distance():
    # Simulate distance measurement (in centimeters)
    # Here, we randomly generate a distance between 0 and 200cm
    import random
    return random.randint(0, 200)

def detect_collision(frame, distance_threshold=10, object_area_threshold=50):
    # Function to detect collision based on distance measurement and object area
    distance = measure_distance()
    if distance <= distance_threshold:
        return True
    else:
        # Convert frame to grayscale
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        # Apply Gaussian blur to reduce noise
        blurred = cv2.GaussianBlur(gray, (5, 5), 0)
        # Perform edge detection
        edges = cv2.Canny(blurred, 50, 150)
        # Find contours
        contours, _ = cv2.findContours(edges.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        # Check if any object with area greater than threshold is detected
        for contour in contours:
            if cv2.contourArea(contour) > object_area_threshold:
                return True
        return False

def save_data(label, frame):
    # Save label and corresponding image to CSV file
    global DATA_FILE, OUTPUT_DIR
    with open(DATA_FILE, mode='a', newline='') as file:
        writer = csv.writer(file)
        image_path = os.path.join(OUTPUT_DIR, f"{label}_{len(os.listdir(OUTPUT_DIR))}.jpg")
        writer.writerow([label, image_path])
    cv2.imwrite(image_path, frame)

def main():
    # Accessing the webcam
    cap = cv2.VideoCapture(0)

    # Variable to control start/stop of data collection
    collecting_data = False

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        # Display the frame
        cv2.imshow('Webcam', frame)

        # Check for collision
        collision_detected = detect_collision(frame)

        if collecting_data:
            if collision_detected:
                print("Collision detected!")
                label = 1
            else:
                print("No collision detected.")
                label = 0

            # Save collision label and corresponding image
            save_data(label, frame)
            print("Data saved.")

        # Break the loop if 'q' is pressed
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('s'):  # Start/Stop data collection
            collecting_data = not collecting_data
            if collecting_data:
                print("Data collection started.")
            else:
                print("Data collection stopped.")

    # Release the webcam and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    # Define output directory and data file
    OUTPUT_DIR = "images"
    DATA_FILE = "collision_data.csv"

    # Create output directory if it doesn't exist
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    # Create or clear the data file
    with open(DATA_FILE, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Label', 'Image'])

    main()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19864/314479156.py in <module>
#      94
#      95     # Create or clear the data file
# ---> 96     with open(DATA_FILE, mode='w', newline='') as file:
#      97         writer = csv.writer(file)
#      98         writer.writerow(['Label', 'Image'])
#
# PermissionError: [Errno 13] Permission denied: 'collision_data.csv'

# %%
import cv2
import numpy as np
import csv
import os
from tensorflow.keras.models import model_from_json

def save_data(label, frame):
    # Save label and corresponding image to CSV file
    global DATA_FILE, OUTPUT_DIR
    with open(DATA_FILE, mode='a', newline='') as file:
        writer = csv.writer(file)
        image_path = os.path.join(OUTPUT_DIR, f"{label}_{len(os.listdir(OUTPUT_DIR))}.jpg")
        writer.writerow([label, image_path])
    cv2.imwrite(image_path, frame)

def main():
    # Load the trained model
    with open('model_struct.json', 'r') as json_file:
        model_json = json_file.read()

    model = model_from_json(model_json)
    model.load_weights('model_weights_49.h5')
    model.compile(loss='mse', optimizer='sgd')

    # Accessing the webcam
    cap = cv2.VideoCapture(0)

    # Define output directory and data file
    OUTPUT_DIR = "images"
    DATA_FILE = "collision_data.csv"

    # Create output directory if it doesn't exist
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    # Create or clear the data file
    with open(DATA_FILE, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Label', 'Image'])

    # Variable to control start/stop of data collection
    collecting_data = False

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        # Display the frame
        cv2.imshow('DroNet', frame)

        # Check for collision
        grayed = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        resized = cv2.resize(grayed, (200, 200))
        norm = resized / 255.0
        image = np.expand_dims(norm, axis=[0, -1])
        prediction = model.predict(image)

        if collecting_data:
            if prediction[0][0] > 0.8:
                print("Collision detected!")
                label = 1
            else:
                print("No collision detected.")
                label = 0

            # Save collision label and corresponding image
            save_data(label, frame)
            print("Data saved.")

        # Break the loop if 'q' is pressed
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('s'):  # Start/Stop data collection
            collecting_data = not collecting_data
            if collecting_data:
                print("Data collection started.")
            else:
                print("Data collection stopped.")

    # Release the webcam and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# ...
# 1/1 [==============================] - 0s 35ms/step

# %%
import cv2
import numpy as np
import csv
import os
import time

# Function to simulate distance measurement
def measure_distance():
    # Simulate distance measurement (in centimeters)
    # Here, we randomly generate a distance between 0 and 200cm
    import random
    return random.randint(0, 200)

# Load the trained model
def load_model():
    with open('model_struct.json', 'r') as json_file:
        model_json = json_file.read()
    model = model_from_json(model_json)
    model.load_weights('model_weights_49.h5')
    model.compile(loss='mse', optimizer='sgd')
    return model

# Function to predict collision using the loaded model
def predict_collision(frame, model):
    grayed = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    resized = cv2.resize(grayed, (200, 200))
    norm = resized / 255.0
    image = np.expand_dims(norm, axis=[0, -1])
    prediction = model.predict(image)
    return prediction[0][0] > 0.8  # Assuming 0.8 as the threshold for collision prediction

# Function to save data (label and corresponding image) to CSV file
def save_data(label, frame):
    global DATA_FILE, OUTPUT_DIR
    with open(DATA_FILE, mode='a', newline='') as file:
        writer = csv.writer(file)
        image_path = os.path.join(OUTPUT_DIR, f"{label}_{int(time.time())}.jpg")
        writer.writerow([label, image_path])
    cv2.imwrite(image_path, frame)

def main():
    # Load the model
    model = load_model()

    # Accessing the webcam
    cap = cv2.VideoCapture(0)

    # Variable to control start/stop of data collection
    collecting_data = False

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        # Display the frame
        cv2.imshow('DroNet', frame)

        # Check for collision
        if collecting_data:
            collision_detected = measure_distance() <= 100  # Simulated distance measurement
            if collision_detected:
                print("Collision detected!")
                label = 1
            else:
                print("No collision detected.")
                label = 0

            # Save collision label and corresponding image
            save_data(label, frame)
            print("Data saved.")

        # Break the loop if 'q' is pressed
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('s'):  # Start/Stop data collection
            collecting_data = not collecting_data
            if collecting_data:
                print("Data collection started.")
            else:
                print("Data collection stopped.")

    # Release the webcam and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    # Define output directory and data file
    OUTPUT_DIR = "images"
    DATA_FILE = "collision_data.csv"

    # Create output directory if it doesn't exist
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    # Create or clear the data file
    with open(DATA_FILE, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Label', 'Image'])

    main()
# Out:
# Data collection started.
# No collision detected.
# Data saved.
# Collision detected!
# Data saved.
# No collision detected.
# Data saved.
# Collision detected!
# Data saved.
# No collision detected.
# Data saved.
# No collision detected.
# Data saved.
# No collision detected.
# Data saved.
# Collision detected!
# Data saved.
# No collision detected.
# Data saved.
# Collision detected!
# Data saved.
# No collision detected.
# Data saved.
# No collision detected.
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# Collision detected!
# Data saved.
# No collision detected.
# Data saved.
# No collision detected.
# Data saved.
# No collision detected.
# Data saved.
# Collision detected!
# Data saved.
# No collision detected.
# Data saved.
# No collision detected.
# Data saved.
# No collision detected.
# Data saved.
# Collision detected!
# Data saved.
# No collision detected.
# Data saved.
# Collision detected!
# Data saved.
# No collision detected.
# ...

# %%
sq
